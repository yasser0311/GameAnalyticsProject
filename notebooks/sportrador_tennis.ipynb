# %% [markdown]
# ***API Integeration, Data Extracting, Coverting dataFrame for Category & Competition and Storing data in database***

# %%
import requests
import json
import pandas as pd
import sqlite3

# Step 1: Fetch Data from the API
url = "https://api.sportradar.com/tennis/trial/v3/en/competitions.json?api_key=xRFvyVa4aCxkKtS0938LmgHfWGhCR7J500ggKWmS"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)
data = response.json()

# Step 2: Parse JSON and Extract Relevant Data
competitions = data.get('competitions', [])

# Step 3: Transform Nested JSON Structures into a Flat Schema
# For simplicity, let's extract some basic fields
flat_data = []
for competition in competitions:
    flat_data.append({
        'id': competition.get('id'),
        'name': competition.get('name'),
        'gender': competition.get('gender'),
        'type': competition.get('type'),
        'category_id': competition.get('category', {}).get('id'),
        'category_name': competition.get('category', {}).get('name')
    })

# Convert to a DataFrame
categories_df = pd.DataFrame(flat_data)
competitions_df = pd.DataFrame(flat_data)

# Step 4: Store Data in a Relational Database
# Create a SQLite database 
conn = sqlite3.connect('sports.db')
categories_df.to_sql('Categories', conn, if_exists='replace', index=False)
competitions_df.to_sql('competitions', conn, index=False, if_exists='replace')

# Verify the data was stored correctly
print("Data stored in the database:")
print(pd.read_sql_query("SELECT * FROM categories", conn))
print(pd.read_sql_query("SELECT * FROM competitions", conn))
# Out:
# Data stored in the database:
#                         id                               name gender     type  \
# 0       sr:competition:620                         Hopman Cup  mixed    mixed
# 1       sr:competition:660                     World Team Cup    men    mixed
# 2       sr:competition:990         ATP Challenger Tour Finals    men  singles
# 3      sr:competition:1207  Championship International Series  women  singles
# 4      sr:competition:2100                          Davis Cup    men    mixed
# ...                    ...                                ...    ...      ...
# 5866  sr:competition:45841      UTR Cornella de Llobregat M03    men  singles
# 5867  sr:competition:45843                   UTR Berkeley M01    men  singles
# 5868  sr:competition:45845                   UTR Yokohama W02  women  singles
# 5869  sr:competition:45847      UTR Cornella de Llobregat W03  women  singles
# 5870  sr:competition:45849                    UTR Pancevo W01  women  singles
#
#            category_id category_name
# 0      sr:category:181    Hopman Cup
# 1        sr:category:3           ATP
# 2       sr:category:72    Challenger
# 3        sr:category:6           WTA
# 4       sr:category:76     Davis Cup
# ...                ...           ...
# 5866  sr:category:2516       UTR Men
# 5867  sr:category:2516       UTR Men
# 5868  sr:category:2517     UTR Women
# 5869  sr:category:2517     UTR Women
# 5870  sr:category:2517     UTR Women
#
# [5871 rows x 6 columns]
#                         id                               name gender     type  \
# 0       sr:competition:620                         Hopman Cup  mixed    mixed
# 1       sr:competition:660                     World Team Cup    men    mixed
# 2       sr:competition:990         ATP Challenger Tour Finals    men  singles
# 3      sr:competition:1207  Championship International Series  women  singles
# 4      sr:competition:2100                          Davis Cup    men    mixed
# ...                    ...                                ...    ...      ...
# 5866  sr:competition:45841      UTR Cornella de Llobregat M03    men  singles
# 5867  sr:competition:45843                   UTR Berkeley M01    men  singles
# 5868  sr:competition:45845                   UTR Yokohama W02  women  singles
# 5869  sr:competition:45847      UTR Cornella de Llobregat W03  women  singles
# 5870  sr:competition:45849                    UTR Pancevo W01  women  singles
#
#            category_id category_name
# 0      sr:category:181    Hopman Cup
# 1        sr:category:3           ATP
# 2       sr:category:72    Challenger
# 3        sr:category:6           WTA
# 4       sr:category:76     Davis Cup
# ...                ...           ...
# 5866  sr:category:2516       UTR Men
# 5867  sr:category:2516       UTR Men
# 5868  sr:category:2517     UTR Women
# 5869  sr:category:2517     UTR Women
# 5870  sr:category:2517     UTR Women
#
# [5871 rows x 6 columns]

# %% [markdown]
# ***API Integeration, Data Extracting, Coverting dataFrame for Complexes & Venues and Storing data in database***

# %%
import requests
import json
import pandas as pd

# Step 1: Fetch Data from the API
url = "https://api.sportradar.com/tennis/trial/v3/en/complexes.json?api_key=xRFvyVa4aCxkKtS0938LmgHfWGhCR7J500ggKWmS"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)
data = response.json()

# Step 2: Parse JSON and Extract Relevant Data
complexes = data.get('complexes', [])

# Step 3: Transform Nested JSON Structures into a Flat Schema
flat_data = []
for complex_ in complexes:
    for venue in complex_.get('venues', []):
        flat_data.append({
            'complex_id': complex_.get('id'),
            'complex_name': complex_.get('name'),
            'venue_id': venue.get('id'),
            'venue_name': venue.get('name'),
            'city_name': venue.get('city'),
            'country_name': venue.get('country'),
            'country_code': venue.get('country_code'),
            'timezone': venue.get('timezone')
        })

# Convert to a DataFrame
complexes_df = pd.DataFrame(flat_data)
venues_df = pd.DataFrame(flat_data)


# Step 4: Store Data in a Relational Database
# Create a SQLite database 
conn = sqlite3.connect('sports.db')
complexes_df.to_sql('complexes', conn, index=False, if_exists='replace')
venues_df.to_sql('Venues', conn, if_exists='replace', index=False)

# Verify the data was stored correctly
print("Data stored in the database:")
print(pd.read_sql_query("SELECT * FROM complexes", conn))
print(pd.read_sql_query("SELECT * FROM venues", conn))
# Out:
# Data stored in the database:
#             complex_id           complex_name        venue_id  \
# 0       sr:complex:705               Nacional  sr:venue:70045
# 1      sr:complex:1078  Estadio de la Cartuja  sr:venue:74856
# 2      sr:complex:1078  Estadio de la Cartuja  sr:venue:74858
# 3      sr:complex:1495            Sibur Arena   sr:venue:1496
# 4      sr:complex:1495            Sibur Arena   sr:venue:1500
# ...                ...                    ...             ...
# 3200  sr:complex:81717            Bloomington  sr:venue:81721
# 3201  sr:complex:81717            Bloomington  sr:venue:81723
# 3202  sr:complex:81717            Bloomington  sr:venue:81725
# 3203  sr:complex:81751  Kallang Tennis Centre  sr:venue:81765
# 3204  sr:complex:81751  Kallang Tennis Centre  sr:venue:81767
#
#                  venue_name city_name country_name country_code  \
# 0            Cancha Central      None         None          CHL
# 1              Centre Court      None         None          ESP
# 2                 Court One      None         None          ESP
# 3                   COURT 1      None         None          RUS
# 4              CENTER COURT      None         None          RUS
# ...                     ...       ...          ...          ...
# 3200  Bloomington - Court 7      None         None          USA
# 3201  Bloomington - Court 6      None         None          USA
# 3202  Bloomington - Court 5      None         None          USA
# 3203           Center Court      None         None          SGP
# 3204                Court 1      None         None          SGP
#
#               timezone
# 0     America/Santiago
# 1        Europe/Madrid
# 2        Europe/Madrid
# 3        Europe/Moscow
# 4        Europe/Moscow
# ...                ...
# 3200  America/New_York
# 3201  America/New_York
# 3202  America/New_York
# 3203    Asia/Singapore
# 3204    Asia/Singapore
#
# [3205 rows x 8 columns]
#             complex_id           complex_name        venue_id  \
# 0       sr:complex:705               Nacional  sr:venue:70045
# 1      sr:complex:1078  Estadio de la Cartuja  sr:venue:74856
# 2      sr:complex:1078  Estadio de la Cartuja  sr:venue:74858
# 3      sr:complex:1495            Sibur Arena   sr:venue:1496
# 4      sr:complex:1495            Sibur Arena   sr:venue:1500
# ...                ...                    ...             ...
# 3200  sr:complex:81717            Bloomington  sr:venue:81721
# 3201  sr:complex:81717            Bloomington  sr:venue:81723
# 3202  sr:complex:81717            Bloomington  sr:venue:81725
# 3203  sr:complex:81751  Kallang Tennis Centre  sr:venue:81765
# 3204  sr:complex:81751  Kallang Tennis Centre  sr:venue:81767
#
#                  venue_name city_name country_name country_code  \
# 0            Cancha Central      None         None          CHL
# 1              Centre Court      None         None          ESP
# 2                 Court One      None         None          ESP
# 3                   COURT 1      None         None          RUS
# 4              CENTER COURT      None         None          RUS
# ...                     ...       ...          ...          ...
# 3200  Bloomington - Court 7      None         None          USA
# 3201  Bloomington - Court 6      None         None          USA
# 3202  Bloomington - Court 5      None         None          USA
# 3203           Center Court      None         None          SGP
# 3204                Court 1      None         None          SGP
#
#               timezone
# 0     America/Santiago
# 1        Europe/Madrid
# 2        Europe/Madrid
# 3        Europe/Moscow
# 4        Europe/Moscow
# ...                ...
# 3200  America/New_York
# 3201  America/New_York
# 3202  America/New_York
# 3203    Asia/Singapore
# 3204    Asia/Singapore
#
# [3205 rows x 8 columns]

# %%
import requests

# Fetch Data from the API
url = "https://api.sportradar.com/tennis/trial/v3/en/double_competitors_rankings.json?api_key=xRFvyVa4aCxkKtS0938LmgHfWGhCR7J500ggKWmS"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)
data = response.json()

# Print the raw JSON data
print(json.dumps(data, indent=4))
# Out:
# {
#     "generated_at": "2025-01-29T12:36:23+00:00",
#     "rankings": [
#         {
#             "type_id": 2,
#             "name": "ATP",
#             "year": 2025,
#             "week": 5,
#             "gender": "men",
#             "competitor_rankings": [
#                 {
#                     "rank": 1,
#                     "movement": 0,
#                     "points": 7530,
#                     "competitions_played": 22,
#                     "competitor": {
#                         "id": "sr:competitor:49363",
#                         "name": "Pavic, Mate",
#                         "country": "Croatia",
#                         "country_code": "HRV",
#                         "abbreviation": "PAV"
#                     }
#                 },
#                 {
#                     "rank": 1,
#                     "movement": 0,
#                     "points": 7530,
#                     "competitions_played": 22,
#                     "competitor": {
#                         "id": "sr:competitor:51836",
#                         "name": "Arevalo-Gonzalez, Marcelo",
#                         "country": "El Salvador",
#                         "country_code": "SLV",
#                         "abbreviation": "ARE"
#                     }
#                 },
#                 {
#                     "rank": 3,
#                     "movement": 10,
#                     "points": 7075,
#                     "competitions_played": 31,
#                     "competitor": {
#                         "id": "sr:competitor:637970",
#                         "name": "Patten, Henry",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "PAT"
#                     }
#                 },
#                 {
#                     "rank": 4,
#                     "movement": 10,
#                     "points": 7055,
#                     "competitions_played": 28,
#                     "competitor": {
#                         "id": "sr:competitor:14898",
#                         "name": "Heliovaara, Harri",
#                         "country": "Finland",
#                         "country_code": "FIN",
#                         "abbreviation": "HEL"
#                     }
#                 },
#                 {
#                     "rank": 5,
#                     "movement": -2,
#                     "points": 6475,
#                     "competitions_played": 21,
#                     "competitor": {
#                         "id": "sr:competitor:87690",
#                         "name": "Thompson, Jordan",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "THO"
#                     }
#                 },
#                 {
#                     "rank": 6,
#                     "movement": 3,
#                     "points": 6240,
#                     "competitions_played": 20,
#                     "competitor": {
#                         "id": "sr:competitor:36593",
#                         "name": "Krawietz, Kevin",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "KRA"
#                     }
#                 },
#                 {
#                     "rank": 7,
#                     "movement": -3,
#                     "points": 6170,
#                     "competitions_played": 16,
#                     "competitor": {
#                         "id": "sr:competitor:15568",
#                         "name": "Granollers, Marcel",
#                         "country": "Spain",
#                         "country_code": "ESP",
#                         "abbreviation": "GRA"
#                     }
#                 },
#                 {
#                     "rank": 7,
#                     "movement": -3,
#                     "points": 6170,
#                     "competitions_played": 16,
#                     "competitor": {
#                         "id": "sr:competitor:16160",
#                         "name": "Zeballos, Horacio",
#                         "country": "Argentina",
#                         "country_code": "ARG",
#                         "abbreviation": "ZEB"
#                     }
#                 },
#                 {
#                     "rank": 9,
#                     "movement": 1,
#                     "points": 6150,
#                     "competitions_played": 19,
#                     "competitor": {
#                         "id": "sr:competitor:52293",
#                         "name": "Putz, Tim",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "PUT"
#                     }
#                 },
#                 {
#                     "rank": 10,
#                     "movement": -4,
#                     "points": 5990,
#                     "competitions_played": 20,
#                     "competitor": {
#                         "id": "sr:competitor:15310",
#                         "name": "Bolelli, Simone",
#                         "country": "Italy",
#                         "country_code": "ITA",
#                         "abbreviation": "BOL"
#                     }
#                 },
#                 {
#                     "rank": 11,
#                     "movement": -4,
#                     "points": 5990,
#                     "competitions_played": 22,
#                     "competitor": {
#                         "id": "sr:competitor:95801",
#                         "name": "Vavassori, Andrea",
#                         "country": "Italy",
#                         "country_code": "ITA",
#                         "abbreviation": "VAV"
#                     }
#                 },
#                 {
#                     "rank": 12,
#                     "movement": -4,
#                     "points": 5750,
#                     "competitions_played": 24,
#                     "competitor": {
#                         "id": "sr:competitor:16608",
#                         "name": "Mektic, Nikola",
#                         "country": "Croatia",
#                         "country_code": "HRV",
#                         "abbreviation": "MEK"
#                     }
#                 },
#                 {
#                     "rank": 13,
#                     "movement": -1,
#                     "points": 5550,
#                     "competitions_played": 19,
#                     "competitor": {
#                         "id": "sr:competitor:124658",
#                         "name": "Purcell, Max",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "PUR"
#                     }
#                 },
#                 {
#                     "rank": 14,
#                     "movement": -3,
#                     "points": 5545,
#                     "competitions_played": 21,
#                     "competitor": {
#                         "id": "sr:competitor:50954",
#                         "name": "Koolhof, Wesley",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "KOO"
#                     }
#                 },
#                 {
#                     "rank": 15,
#                     "movement": 2,
#                     "points": 4025,
#                     "competitions_played": 28,
#                     "competitor": {
#                         "id": "sr:competitor:16151",
#                         "name": "Venus, Michael",
#                         "country": "New Zealand",
#                         "country_code": "NZL",
#                         "abbreviation": "VEN"
#                     }
#                 },
#                 {
#                     "rank": 16,
#                     "movement": 2,
#                     "points": 3580,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:53785",
#                         "name": "Skupski, Neal",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "SKU"
#                     }
#                 },
#                 {
#                     "rank": 17,
#                     "movement": 3,
#                     "points": 3230,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:55989",
#                         "name": "Withrow, Jackson",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "WIT"
#                     }
#                 },
#                 {
#                     "rank": 17,
#                     "movement": 3,
#                     "points": 3230,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:210736",
#                         "name": "Lammons, Nathaniel",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "LAM"
#                     }
#                 },
#                 {
#                     "rank": 19,
#                     "movement": 4,
#                     "points": 3120,
#                     "competitions_played": 35,
#                     "competitor": {
#                         "id": "sr:competitor:59131",
#                         "name": "Glasspool, Lloyd",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "GLA"
#                     }
#                 },
#                 {
#                     "rank": 20,
#                     "movement": -5,
#                     "points": 3105,
#                     "competitions_played": 20,
#                     "competitor": {
#                         "id": "sr:competitor:16409",
#                         "name": "Ebden, Matthew",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "EBD"
#                     }
#                 },
#                 {
#                     "rank": 21,
#                     "movement": -5,
#                     "points": 3000,
#                     "competitions_played": 20,
#                     "competitor": {
#                         "id": "sr:competitor:15307",
#                         "name": "Bopanna, Rohan",
#                         "country": "India",
#                         "country_code": "IND",
#                         "abbreviation": "BRO"
#                     }
#                 },
#                 {
#                     "rank": 22,
#                     "movement": -3,
#                     "points": 2970,
#                     "competitions_played": 24,
#                     "competitor": {
#                         "id": "sr:competitor:38181",
#                         "name": "Molteni, Andres",
#                         "country": "Argentina",
#                         "country_code": "ARG",
#                         "abbreviation": "MOL"
#                     }
#                 },
#                 {
#                     "rank": 23,
#                     "movement": 5,
#                     "points": 2910,
#                     "competitions_played": 28,
#                     "competitor": {
#                         "id": "sr:competitor:106349",
#                         "name": "Reboul, Fabien",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "REB"
#                     }
#                 },
#                 {
#                     "rank": 24,
#                     "movement": 7,
#                     "points": 2875,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:108099",
#                         "name": "Cash, Julian",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "CAS"
#                     }
#                 },
#                 {
#                     "rank": 25,
#                     "movement": -1,
#                     "points": 2870,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:52202",
#                         "name": "Nys, Hugo",
#                         "country": "Monaco",
#                         "country_code": "MCO",
#                         "abbreviation": "NYS"
#                     }
#                 },
#                 {
#                     "rank": 26,
#                     "movement": 1,
#                     "points": 2800,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:47834",
#                         "name": "Murray, Jamie",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "MUR"
#                     }
#                 },
#                 {
#                     "rank": 27,
#                     "movement": -5,
#                     "points": 2790,
#                     "competitions_played": 19,
#                     "competitor": {
#                         "id": "sr:competitor:15548",
#                         "name": "Gonzalez, Maximo",
#                         "country": "Argentina",
#                         "country_code": "ARG",
#                         "abbreviation": "GON"
#                     }
#                 },
#                 {
#                     "rank": 28,
#                     "movement": -2,
#                     "points": 2760,
#                     "competitions_played": 25,
#                     "competitor": {
#                         "id": "sr:competitor:16275",
#                         "name": "Dodig, Ivan",
#                         "country": "Croatia",
#                         "country_code": "HRV",
#                         "abbreviation": "DOD"
#                     }
#                 },
#                 {
#                     "rank": 29,
#                     "movement": 3,
#                     "points": 2630,
#                     "competitions_played": 33,
#                     "competitor": {
#                         "id": "sr:competitor:206889",
#                         "name": "Galloway, Robert",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "GAL"
#                     }
#                 },
#                 {
#                     "rank": 30,
#                     "movement": -5,
#                     "points": 2600,
#                     "competitions_played": 25,
#                     "competitor": {
#                         "id": "sr:competitor:112805",
#                         "name": "Zielinski, Jan",
#                         "country": "Poland",
#                         "country_code": "POL",
#                         "abbreviation": "ZIE"
#                     }
#                 },
#                 {
#                     "rank": 31,
#                     "movement": -2,
#                     "points": 2595,
#                     "competitions_played": 23,
#                     "competitor": {
#                         "id": "sr:competitor:14553",
#                         "name": "Ram, Rajeev",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "RAM"
#                     }
#                 },
#                 {
#                     "rank": 32,
#                     "movement": 7,
#                     "points": 2550,
#                     "competitions_played": 25,
#                     "competitor": {
#                         "id": "sr:competitor:14835",
#                         "name": "Roger-Vasselin, Edouard",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "ROG"
#                     }
#                 },
#                 {
#                     "rank": 33,
#                     "movement": 3,
#                     "points": 2515,
#                     "competitions_played": 33,
#                     "competitor": {
#                         "id": "sr:competitor:106559",
#                         "name": "Doumbia, Sadio",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "DOU"
#                     }
#                 },
#                 {
#                     "rank": 34,
#                     "movement": 3,
#                     "points": 2485,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:81059",
#                         "name": "Gille, Sander",
#                         "country": "Belgium",
#                         "country_code": "BEL",
#                         "abbreviation": "GIL"
#                     }
#                 },
#                 {
#                     "rank": 35,
#                     "movement": -2,
#                     "points": 2445,
#                     "competitions_played": 31,
#                     "competitor": {
#                         "id": "sr:competitor:56629",
#                         "name": "Peers, John",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "PEE"
#                     }
#                 },
#                 {
#                     "rank": 36,
#                     "movement": -2,
#                     "points": 2440,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:104917",
#                         "name": "Vliegen, Joran",
#                         "country": "Belgium",
#                         "country_code": "BEL",
#                         "abbreviation": "VLI"
#                     }
#                 },
#                 {
#                     "rank": 37,
#                     "movement": -7,
#                     "points": 2325,
#                     "competitions_played": 26,
#                     "competitor": {
#                         "id": "sr:competitor:59324",
#                         "name": "Pavlasek, Adam",
#                         "country": "Czechia",
#                         "country_code": "CZE",
#                         "abbreviation": "PAV"
#                     }
#                 },
#                 {
#                     "rank": 38,
#                     "movement": -3,
#                     "points": 2302,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:76263",
#                         "name": "Matos, Rafael",
#                         "country": "Brazil",
#                         "country_code": "BRA",
#                         "abbreviation": "MAT"
#                     }
#                 },
#                 {
#                     "rank": 39,
#                     "movement": -1,
#                     "points": 2295,
#                     "competitions_played": 26,
#                     "competitor": {
#                         "id": "sr:competitor:16124",
#                         "name": "Melo, Marcelo",
#                         "country": "Brazil",
#                         "country_code": "BRA",
#                         "abbreviation": "MEL"
#                     }
#                 },
#                 {
#                     "rank": 40,
#                     "movement": 15,
#                     "points": 2245,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:230186",
#                         "name": "Verbeek, Sem",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "VER"
#                     }
#                 },
#                 {
#                     "rank": 41,
#                     "movement": 2,
#                     "points": 2160,
#                     "competitions_played": 22,
#                     "competitor": {
#                         "id": "sr:competitor:25189",
#                         "name": "Krajicek, Austin",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "KRA"
#                     }
#                 },
#                 {
#                     "rank": 42,
#                     "movement": -1,
#                     "points": 2152,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:114831",
#                         "name": "Erler, Alexander",
#                         "country": "Austria",
#                         "country_code": "AUT",
#                         "abbreviation": "ERL"
#                     }
#                 },
#                 {
#                     "rank": 43,
#                     "movement": -3,
#                     "points": 2130,
#                     "competitions_played": 20,
#                     "competitor": {
#                         "id": "sr:competitor:74173",
#                         "name": "Salisbury, Joe",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "SAL"
#                     }
#                 },
#                 {
#                     "rank": 44,
#                     "movement": 2,
#                     "points": 2038,
#                     "competitions_played": 30,
#                     "competitor": {
#                         "id": "sr:competitor:78793",
#                         "name": "Miedler, Lucas",
#                         "country": "Austria",
#                         "country_code": "AUT",
#                         "abbreviation": "MIE"
#                     }
#                 },
#                 {
#                     "rank": 45,
#                     "movement": -1,
#                     "points": 1940,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:47966",
#                         "name": "Olivetti, Albano",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "OLI"
#                     }
#                 },
#                 {
#                     "rank": 46,
#                     "movement": -4,
#                     "points": 1931,
#                     "competitions_played": 27,
#                     "competitor": {
#                         "id": "sr:competitor:45105",
#                         "name": "Behar, Ariel",
#                         "country": "Uruguay",
#                         "country_code": "URY",
#                         "abbreviation": "BEH"
#                     }
#                 },
#                 {
#                     "rank": 47,
#                     "movement": 0,
#                     "points": 1895,
#                     "competitions_played": 26,
#                     "competitor": {
#                         "id": "sr:competitor:22967",
#                         "name": "Bhambri, Yuki",
#                         "country": "India",
#                         "country_code": "IND",
#                         "abbreviation": "BHA"
#                     }
#                 },
#                 {
#                     "rank": 48,
#                     "movement": 20,
#                     "points": 1895,
#                     "competitions_played": 30,
#                     "competitor": {
#                         "id": "sr:competitor:70348",
#                         "name": "Goransson, Andre",
#                         "country": "Sweden",
#                         "country_code": "SWE",
#                         "abbreviation": "GOR"
#                     }
#                 },
#                 {
#                     "rank": 49,
#                     "movement": -4,
#                     "points": 1890,
#                     "competitions_played": 30,
#                     "competitor": {
#                         "id": "sr:competitor:15305",
#                         "name": "Gonzalez, Santiago",
#                         "country": "Mexico",
#                         "country_code": "MEX",
#                         "abbreviation": "GON"
#                     }
#                 },
#                 {
#                     "rank": 50,
#                     "movement": 2,
#                     "points": 1775,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:66864",
#                         "name": "Arends, Sander",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "ARE"
#                     }
#                 },
#                 {
#                     "rank": 51,
#                     "movement": -3,
#                     "points": 1770,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:48646",
#                         "name": "Barrientos, Nicolas",
#                         "country": "Colombia",
#                         "country_code": "COL",
#                         "abbreviation": "BAR"
#                     }
#                 },
#                 {
#                     "rank": 52,
#                     "movement": -1,
#                     "points": 1680,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:15588",
#                         "name": "Rojer, Jean-Julien",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "ROJ"
#                     }
#                 },
#                 {
#                     "rank": 53,
#                     "movement": 0,
#                     "points": 1658,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:62410",
#                         "name": "Johnson, Luke",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "JOH"
#                     }
#                 },
#                 {
#                     "rank": 54,
#                     "movement": 3,
#                     "points": 1586,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:108755",
#                         "name": "Jebens, Hendrik",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "JEB"
#                     }
#                 },
#                 {
#                     "rank": 54,
#                     "movement": 3,
#                     "points": 1586,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:231188",
#                         "name": "Frantzen, Constantin",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "FRA"
#                     }
#                 },
#                 {
#                     "rank": 56,
#                     "movement": -2,
#                     "points": 1580,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:69362",
#                         "name": "Mansouri, Skander",
#                         "country": "Tunisia",
#                         "country_code": "TUN",
#                         "abbreviation": "MAN"
#                     }
#                 },
#                 {
#                     "rank": 57,
#                     "movement": -1,
#                     "points": 1550,
#                     "competitions_played": 33,
#                     "competitor": {
#                         "id": "sr:competitor:47295",
#                         "name": "Andreozzi, Guido",
#                         "country": "Argentina",
#                         "country_code": "ARG",
#                         "abbreviation": "AND"
#                     }
#                 },
#                 {
#                     "rank": 58,
#                     "movement": 1,
#                     "points": 1467,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:49306",
#                         "name": "Reyes-Varela, Miguel",
#                         "country": "Mexico",
#                         "country_code": "MEX",
#                         "abbreviation": "REY"
#                     }
#                 },
#                 {
#                     "rank": 59,
#                     "movement": 17,
#                     "points": 1419,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:127646",
#                         "name": "Cabral, Francisco",
#                         "country": "Portugal",
#                         "country_code": "PRT",
#                         "abbreviation": "CAB"
#                     }
#                 },
#                 {
#                     "rank": 60,
#                     "movement": 0,
#                     "points": 1401,
#                     "competitions_played": 26,
#                     "competitor": {
#                         "id": "sr:competitor:25457",
#                         "name": "Nedovyesov, Aleksandr",
#                         "country": "Kazakhstan",
#                         "country_code": "KAZ",
#                         "abbreviation": "NED"
#                     }
#                 },
#                 {
#                     "rank": 61,
#                     "movement": 3,
#                     "points": 1395,
#                     "competitions_played": 31,
#                     "competitor": {
#                         "id": "sr:competitor:81763",
#                         "name": "Jacq, Gregoire",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "JAC"
#                     }
#                 },
#                 {
#                     "rank": 62,
#                     "movement": 0,
#                     "points": 1380,
#                     "competitions_played": 25,
#                     "competitor": {
#                         "id": "sr:competitor:16198",
#                         "name": "Escobar, Gonzalo",
#                         "country": "Ecuador",
#                         "country_code": "ECU",
#                         "abbreviation": "ESC"
#                     }
#                 },
#                 {
#                     "rank": 63,
#                     "movement": 3,
#                     "points": 1355,
#                     "competitions_played": 35,
#                     "competitor": {
#                         "id": "sr:competitor:111195",
#                         "name": "Luz, Orlando",
#                         "country": "Brazil",
#                         "country_code": "BRA",
#                         "abbreviation": "LUZ"
#                     }
#                 },
#                 {
#                     "rank": 64,
#                     "movement": 1,
#                     "points": 1316,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:52244",
#                         "name": "Balaji, N. Sriram",
#                         "country": "India",
#                         "country_code": "IND",
#                         "abbreviation": "BAL"
#                     }
#                 },
#                 {
#                     "rank": 65,
#                     "movement": -2,
#                     "points": 1310,
#                     "competitions_played": 43,
#                     "competitor": {
#                         "id": "sr:competitor:231090",
#                         "name": "Arribage, Theo",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "ARR"
#                     }
#                 },
#                 {
#                     "rank": 66,
#                     "movement": -17,
#                     "points": 1285,
#                     "competitions_played": 11,
#                     "competitor": {
#                         "id": "sr:competitor:300540",
#                         "name": "Machac, Tomas",
#                         "country": "Czechia",
#                         "country_code": "CZE",
#                         "abbreviation": "MAC"
#                     }
#                 },
#                 {
#                     "rank": 67,
#                     "movement": 0,
#                     "points": 1270,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:203681",
#                         "name": "Korda, Sebastian",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "KOR"
#                     }
#                 },
#                 {
#                     "rank": 68,
#                     "movement": -7,
#                     "points": 1270,
#                     "competitions_played": 26,
#                     "competitor": {
#                         "id": "sr:competitor:104421",
#                         "name": "Mies, Andreas",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "MIE"
#                     }
#                 },
#                 {
#                     "rank": 69,
#                     "movement": -19,
#                     "points": 1240,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:75813",
#                         "name": "Zhang, Zhizhen",
#                         "country": "China",
#                         "country_code": "CHN",
#                         "abbreviation": "ZHA"
#                     }
#                 },
#                 {
#                     "rank": 70,
#                     "movement": 1,
#                     "points": 1206,
#                     "competitions_played": 31,
#                     "competitor": {
#                         "id": "sr:competitor:16042",
#                         "name": "Haase, Robin",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "HAA"
#                     }
#                 },
#                 {
#                     "rank": 71,
#                     "movement": 6,
#                     "points": 1190,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:41475",
#                         "name": "Arneodo, Romain",
#                         "country": "Monaco",
#                         "country_code": "MCO",
#                         "abbreviation": "ARN"
#                     }
#                 },
#                 {
#                     "rank": 72,
#                     "movement": -3,
#                     "points": 1185,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:17038",
#                         "name": "Smith, John-Patrick",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "SMI"
#                     }
#                 },
#                 {
#                     "rank": 73,
#                     "movement": 0,
#                     "points": 1182,
#                     "competitions_played": 32,
#                     "competitor": {
#                         "id": "sr:competitor:204781",
#                         "name": "Nouza, Petr",
#                         "country": "Czechia",
#                         "country_code": "CZE",
#                         "abbreviation": "NOU"
#                     }
#                 },
#                 {
#                     "rank": 74,
#                     "movement": -4,
#                     "points": 1176,
#                     "competitions_played": 24,
#                     "competitor": {
#                         "id": "sr:competitor:121182",
#                         "name": "Guinard, Manuel",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "GUI"
#                     }
#                 },
#                 {
#                     "rank": 75,
#                     "movement": -1,
#                     "points": 1155,
#                     "competitions_played": 30,
#                     "competitor": {
#                         "id": "sr:competitor:152900",
#                         "name": "Rikl, Patrik",
#                         "country": "Czechia",
#                         "country_code": "CZE",
#                         "abbreviation": "RIK"
#                     }
#                 },
#                 {
#                     "rank": 76,
#                     "movement": -1,
#                     "points": 1136,
#                     "competitions_played": 37,
#                     "competitor": {
#                         "id": "sr:competitor:52065",
#                         "name": "Harrison, Christian",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "HAR"
#                     }
#                 },
#                 {
#                     "rank": 77,
#                     "movement": 3,
#                     "points": 1133,
#                     "competitions_played": 41,
#                     "competitor": {
#                         "id": "sr:competitor:112969",
#                         "name": "Schnaitter, Jakob",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "SCH"
#                     }
#                 },
#                 {
#                     "rank": 77,
#                     "movement": 3,
#                     "points": 1133,
#                     "competitions_played": 41,
#                     "competitor": {
#                         "id": "sr:competitor:936355",
#                         "name": "Wallner, Mark",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "WAL"
#                     }
#                 },
#                 {
#                     "rank": 79,
#                     "movement": -7,
#                     "points": 1132,
#                     "competitions_played": 33,
#                     "competitor": {
#                         "id": "sr:competitor:918463",
#                         "name": "Bollipalli, Rithvik Choudary",
#                         "country": "India",
#                         "country_code": "IND",
#                         "abbreviation": "BOL"
#                     }
#                 },
#                 {
#                     "rank": 80,
#                     "movement": 2,
#                     "points": 1130,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:16043",
#                         "name": "Middelkoop, Matwe",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "MID"
#                     }
#                 },
#                 {
#                     "rank": 81,
#                     "movement": -2,
#                     "points": 1118,
#                     "competitions_played": 38,
#                     "competitor": {
#                         "id": "sr:competitor:23899",
#                         "name": "King, Evan",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "KIN"
#                     }
#                 },
#                 {
#                     "rank": 82,
#                     "movement": -4,
#                     "points": 1056,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:287215",
#                         "name": "Seggerman, Ryan",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "SEG"
#                     }
#                 },
#                 {
#                     "rank": 83,
#                     "movement": 1,
#                     "points": 1042,
#                     "competitions_played": 28,
#                     "competitor": {
#                         "id": "sr:competitor:76361",
#                         "name": "Kadhe, Arjun",
#                         "country": "India",
#                         "country_code": "IND",
#                         "abbreviation": "KAD"
#                     }
#                 },
#                 {
#                     "rank": 84,
#                     "movement": -1,
#                     "points": 1039,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:223868",
#                         "name": "Matuszewski, Piotr",
#                         "country": "Poland",
#                         "country_code": "POL",
#                         "abbreviation": "MAT"
#                     }
#                 },
#                 {
#                     "rank": 85,
#                     "movement": 3,
#                     "points": 1035,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:52263",
#                         "name": "Hidalgo, Diego",
#                         "country": "Ecuador",
#                         "country_code": "ECU",
#                         "abbreviation": "HID"
#                     }
#                 },
#                 {
#                     "rank": 86,
#                     "movement": 0,
#                     "points": 1030,
#                     "competitions_played": 12,
#                     "competitor": {
#                         "id": "sr:competitor:63438",
#                         "name": "McDonald, Mackenzie",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "MCD"
#                     }
#                 },
#                 {
#                     "rank": 87,
#                     "movement": 4,
#                     "points": 968,
#                     "competitions_played": 39,
#                     "competitor": {
#                         "id": "sr:competitor:77653",
#                         "name": "Cornea, Victor",
#                         "country": "Romania",
#                         "country_code": "ROU",
#                         "abbreviation": "COR"
#                     }
#                 },
#                 {
#                     "rank": 88,
#                     "movement": 9,
#                     "points": 961,
#                     "competitions_played": 39,
#                     "competitor": {
#                         "id": "sr:competitor:147104",
#                         "name": "Romios, Matthew Christopher",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "ROM"
#                     }
#                 },
#                 {
#                     "rank": 89,
#                     "movement": 0,
#                     "points": 960,
#                     "competitions_played": 7,
#                     "competitor": {
#                         "id": "sr:competitor:57163",
#                         "name": "Zverev, Alexander",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "ZVE"
#                     }
#                 },
#                 {
#                     "rank": 90,
#                     "movement": 4,
#                     "points": 915,
#                     "competitions_played": 9,
#                     "competitor": {
#                         "id": "sr:competitor:871495",
#                         "name": "Michelsen, Alex",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "MIC"
#                     }
#                 },
#                 {
#                     "rank": 91,
#                     "movement": 14,
#                     "points": 901,
#                     "competitions_played": 29,
#                     "competitor": {
#                         "id": "sr:competitor:197678",
#                         "name": "Tsitsipas, Petros",
#                         "country": "Greece",
#                         "country_code": "GRC",
#                         "abbreviation": "TSI"
#                     }
#                 },
#                 {
#                     "rank": 92,
#                     "movement": 3,
#                     "points": 897,
#                     "competitions_played": 33,
#                     "competitor": {
#                         "id": "sr:competitor:16992",
#                         "name": "Willis, Marcus",
#                         "country": "Great Britain",
#                         "country_code": "GBR",
#                         "abbreviation": "WIL"
#                     }
#                 },
#                 {
#                     "rank": 93,
#                     "movement": 0,
#                     "points": 892,
#                     "competitions_played": 36,
#                     "competitor": {
#                         "id": "sr:competitor:73572",
#                         "name": "Zormann, Marcelo",
#                         "country": "Brazil",
#                         "country_code": "BRA",
#                         "abbreviation": "ZOR"
#                     }
#                 },
#                 {
#                     "rank": 94,
#                     "movement": 5,
#                     "points": 882,
#                     "competitions_played": 35,
#                     "competitor": {
#                         "id": "sr:competitor:16492",
#                         "name": "Eysseric, Jonathan",
#                         "country": "France",
#                         "country_code": "FRA",
#                         "abbreviation": "EYS"
#                     }
#                 },
#                 {
#                     "rank": 95,
#                     "movement": -5,
#                     "points": 858,
#                     "competitions_played": 34,
#                     "competitor": {
#                         "id": "sr:competitor:1020797",
#                         "name": "Trhac, Patrik",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "TRH"
#                     }
#                 },
#                 {
#                     "rank": 96,
#                     "movement": 6,
#                     "points": 855,
#                     "competitions_played": 13,
#                     "competitor": {
#                         "id": "sr:competitor:808628",
#                         "name": "Shelton, Ben",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "SHE"
#                     }
#                 },
#                 {
#                     "rank": 97,
#                     "movement": 3,
#                     "points": 855,
#                     "competitions_played": 39,
#                     "competitor": {
#                         "id": "sr:competitor:16823",
#                         "name": "Romboli, Fernando",
#                         "country": "Brazil",
#                         "country_code": "BRA",
#                         "abbreviation": "ROM"
#                     }
#                 },
#                 {
#                     "rank": 98,
#                     "movement": -6,
#                     "points": 847,
#                     "competitions_played": 19,
#                     "competitor": {
#                         "id": "sr:competitor:299130",
#                         "name": "Hijikata, Rinky",
# ...
#                         "country": "Canada",
#                         "country_code": "CAN",
#                         "abbreviation": "STA"
#                     }
#                 },
#                 {
#                     "rank": 468,
#                     "movement": 61,
#                     "points": 136,
#                     "competitions_played": 9,
#                     "competitor": {
#                         "id": "sr:competitor:431743",
#                         "name": "Okutoyi, Angella",
#                         "country": "Kenya",
#                         "country_code": "KEN",
#                         "abbreviation": "OKU"
#                     }
#                 },
#                 {
#                     "rank": 469,
#                     "movement": 40,
#                     "points": 136,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:812476",
#                         "name": "Zaytseva, Ksenia",
#                         "country": "Neutral",
#                         "abbreviation": "ZAY"
#                     }
#                 },
#                 {
#                     "rank": 470,
#                     "movement": 5,
#                     "points": 136,
#                     "competitions_played": 16,
#                     "competitor": {
#                         "id": "sr:competitor:476218",
#                         "name": "Kawaguchi, Natsumi",
#                         "country": "Japan",
#                         "country_code": "JPN",
#                         "abbreviation": "KAW"
#                     }
#                 },
#                 {
#                     "rank": 471,
#                     "movement": 6,
#                     "points": 135,
#                     "competitions_played": 13,
#                     "competitor": {
#                         "id": "sr:competitor:739667",
#                         "name": "Pedone, Giorgia",
#                         "country": "Italy",
#                         "country_code": "ITA",
#                         "abbreviation": "PED"
#                     }
#                 },
#                 {
#                     "rank": 472,
#                     "movement": 6,
#                     "points": 135,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:342788",
#                         "name": "Curmi, Francesca",
#                         "country": "Malta",
#                         "country_code": "MLT",
#                         "abbreviation": "CUR"
#                     }
#                 },
#                 {
#                     "rank": 473,
#                     "movement": 6,
#                     "points": 133,
#                     "competitions_played": 22,
#                     "competitor": {
#                         "id": "sr:competitor:265743",
#                         "name": "Burdina, Evgeniya",
#                         "country": "Neutral",
#                         "abbreviation": "BUR"
#                     }
#                 },
#                 {
#                     "rank": 474,
#                     "movement": 6,
#                     "points": 132,
#                     "competitions_played": 8,
#                     "competitor": {
#                         "id": "sr:competitor:46661",
#                         "name": "Gamiz, Andrea",
#                         "country": "Venezuela",
#                         "country_code": "VEN",
#                         "abbreviation": "GAM"
#                     }
#                 },
#                 {
#                     "rank": 475,
#                     "movement": 76,
#                     "points": 132,
#                     "competitions_played": 13,
#                     "competitor": {
#                         "id": "sr:competitor:340365",
#                         "name": "Milovanovic, Elena",
#                         "country": "Serbia",
#                         "country_code": "SRB",
#                         "abbreviation": "MIL"
#                     }
#                 },
#                 {
#                     "rank": 476,
#                     "movement": -15,
#                     "points": 131,
#                     "competitions_played": 2,
#                     "competitor": {
#                         "id": "sr:competitor:19704",
#                         "name": "Martic, Petra",
#                         "country": "Croatia",
#                         "country_code": "HRV",
#                         "abbreviation": "MAR"
#                     }
#                 },
#                 {
#                     "rank": 477,
#                     "movement": 5,
#                     "points": 131,
#                     "competitions_played": 13,
#                     "competitor": {
#                         "id": "sr:competitor:915371",
#                         "name": "van Den Broek, Isis Louise",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "VAN"
#                     }
#                 },
#                 {
#                     "rank": 478,
#                     "movement": 0,
#                     "points": 130,
#                     "competitions_played": 1,
#                     "competitor": {
#                         "id": "sr:competitor:71034",
#                         "name": "Sramkova, Rebecca",
#                         "country": "Slovakia",
#                         "country_code": "SVK",
#                         "abbreviation": "SRA"
#                     }
#                 },
#                 {
#                     "rank": 479,
#                     "movement": -30,
#                     "points": 130,
#                     "competitions_played": 4,
#                     "competitor": {
#                         "id": "sr:competitor:535801",
#                         "name": "Schunk, Nastasja",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "SCH"
#                     }
#                 },
#                 {
#                     "rank": 480,
#                     "movement": 4,
#                     "points": 130,
#                     "competitions_played": 11,
#                     "competitor": {
#                         "id": "sr:competitor:784280",
#                         "name": "Prozorova, Tatiana",
#                         "country": "Neutral",
#                         "abbreviation": "PRO"
#                     }
#                 },
#                 {
#                     "rank": 481,
#                     "movement": 4,
#                     "points": 130,
#                     "competitions_played": 15,
#                     "competitor": {
#                         "id": "sr:competitor:858867",
#                         "name": "Pace, Francesca",
#                         "country": "Italy",
#                         "country_code": "ITA",
#                         "abbreviation": "PAC"
#                     }
#                 },
#                 {
#                     "rank": 482,
#                     "movement": 6,
#                     "points": 129,
#                     "competitions_played": 4,
#                     "competitor": {
#                         "id": "sr:competitor:46651",
#                         "name": "Melnikova, Marina",
#                         "country": "Neutral",
#                         "abbreviation": "MEL"
#                     }
#                 },
#                 {
#                     "rank": 483,
#                     "movement": 7,
#                     "points": 129,
#                     "competitions_played": 15,
#                     "competitor": {
#                         "id": "sr:competitor:827398",
#                         "name": "Stankovic, Anja",
#                         "country": "Serbia",
#                         "country_code": "SRB",
#                         "abbreviation": "STA"
#                     }
#                 },
#                 {
#                     "rank": 484,
#                     "movement": 7,
#                     "points": 128,
#                     "competitions_played": 4,
#                     "competitor": {
#                         "id": "sr:competitor:343160",
#                         "name": "Volynets, Katie",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "VOL"
#                     }
#                 },
#                 {
#                     "rank": 485,
#                     "movement": 7,
#                     "points": 128,
#                     "competitions_played": 9,
#                     "competitor": {
#                         "id": "sr:competitor:686597",
#                         "name": "Pavlova, Kira",
#                         "country": "Neutral",
#                         "abbreviation": "PAV"
#                     }
#                 },
#                 {
#                     "rank": 486,
#                     "movement": 7,
#                     "points": 128,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:833330",
#                         "name": "Grechkina, Anastasia",
#                         "country": "Neutral",
#                         "abbreviation": "GRE"
#                     }
#                 },
#                 {
#                     "rank": 487,
#                     "movement": 7,
#                     "points": 127,
#                     "competitions_played": 20,
#                     "competitor": {
#                         "id": "sr:competitor:447759",
#                         "name": "Katsumi, Nanari",
#                         "country": "Japan",
#                         "country_code": "JPN",
#                         "abbreviation": "KAT"
#                     }
#                 },
#                 {
#                     "rank": 488,
#                     "movement": 9,
#                     "points": 126,
#                     "competitions_played": 4,
#                     "competitor": {
#                         "id": "sr:competitor:39425",
#                         "name": "Savinykh, Valeria",
#                         "country": "Neutral",
#                         "abbreviation": "SAV"
#                     }
#                 },
#                 {
#                     "rank": 489,
#                     "movement": 9,
#                     "points": 126,
#                     "competitions_played": 26,
#                     "competitor": {
#                         "id": "sr:competitor:69964",
#                         "name": "Estable, Julieta",
#                         "country": "Argentina",
#                         "country_code": "ARG",
#                         "abbreviation": "EST"
#                     }
#                 },
#                 {
#                     "rank": 490,
#                     "movement": 9,
#                     "points": 126,
#                     "competitions_played": 9,
#                     "competitor": {
#                         "id": "sr:competitor:18350",
#                         "name": "Voracova, Renata",
#                         "country": "Czechia",
#                         "country_code": "CZE",
#                         "abbreviation": "VOR"
#                     }
#                 },
#                 {
#                     "rank": 491,
#                     "movement": 9,
#                     "points": 125,
#                     "competitions_played": 6,
#                     "competitor": {
#                         "id": "sr:competitor:60276",
#                         "name": "Podoroska, Nadia",
#                         "country": "Argentina",
#                         "country_code": "ARG",
#                         "abbreviation": "POD"
#                     }
#                 },
#                 {
#                     "rank": 492,
#                     "movement": 10,
#                     "points": 125,
#                     "competitions_played": 11,
#                     "competitor": {
#                         "id": "sr:competitor:759784",
#                         "name": "El Aouni, Aya",
#                         "country": "Morocco",
#                         "country_code": "MAR",
#                         "abbreviation": "EL"
#                     }
#                 },
#                 {
#                     "rank": 493,
#                     "movement": 12,
#                     "points": 125,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:378226",
#                         "name": "Crawley, Fiona",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "CRA"
#                     }
#                 },
#                 {
#                     "rank": 494,
#                     "movement": 12,
#                     "points": 125,
#                     "competitions_played": 11,
#                     "competitor": {
#                         "id": "sr:competitor:840734",
#                         "name": "Walker, Brandy",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "WAL"
#                     }
#                 },
#                 {
#                     "rank": 495,
#                     "movement": 35,
#                     "points": 125,
#                     "competitions_played": 12,
#                     "competitor": {
#                         "id": "sr:competitor:262701",
#                         "name": "Hodzic, Mina",
#                         "country": "Germany",
#                         "country_code": "DEU",
#                         "abbreviation": "HOD"
#                     }
#                 },
#                 {
#                     "rank": 496,
#                     "movement": 7,
#                     "points": 124,
#                     "competitions_played": 10,
#                     "competitor": {
#                         "id": "sr:competitor:98733",
#                         "name": "Burillo Escorihuela, Irene",
#                         "country": "Spain",
#                         "country_code": "ESP",
#                         "abbreviation": "BUR"
#                     }
#                 },
#                 {
#                     "rank": 497,
#                     "movement": 10,
#                     "points": 124,
#                     "competitions_played": 4,
#                     "competitor": {
#                         "id": "sr:competitor:32862",
#                         "name": "Diatchenko, Vitalia",
#                         "country": "Neutral",
#                         "abbreviation": "DIA"
#                     }
#                 },
#                 {
#                     "rank": 498,
#                     "movement": 12,
#                     "points": 124,
#                     "competitions_played": 15,
#                     "competitor": {
#                         "id": "sr:competitor:720627",
#                         "name": "Senic, Natalija",
#                         "country": "Serbia",
#                         "country_code": "SRB",
#                         "abbreviation": "SEN"
#                     }
#                 },
#                 {
#                     "rank": 499,
#                     "movement": 12,
#                     "points": 124,
#                     "competitions_played": 21,
#                     "competitor": {
#                         "id": "sr:competitor:360054",
#                         "name": "Allen, Kolie",
#                         "country": "USA",
#                         "country_code": "USA",
#                         "abbreviation": "ALL"
#                     }
#                 },
#                 {
#                     "rank": 500,
#                     "movement": 12,
#                     "points": 123,
#                     "competitions_played": 17,
#                     "competitor": {
#                         "id": "sr:competitor:299308",
#                         "name": "Smith, Tina Nadine",
#                         "country": "Australia",
#                         "country_code": "AUS",
#                         "abbreviation": "SMI"
#                     }
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# ***API Integeration, Data Extracting, Coverting dataFrame for Competitor & competition_ranking and Storing data in database***

# %%
import requests
import pandas as pd
import sqlite3

# Fetch Data from the API
url = "https://api.sportradar.com/tennis/trial/v3/en/double_competitors_rankings.json?api_key=xRFvyVa4aCxkKtS0938LmgHfWGhCR7J500ggKWmS"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)
data = response.json()

# Extract the relevant data
rankings = data.get('rankings', [])

# Transform Nested JSON Structures into a Flat Schema
flat_data = []
for ranking in rankings:
    for competitor_ranking in ranking.get('competitor_rankings', []):
        competitor = competitor_ranking.get('competitor', {})
        flat_data.append({
            'type_id': ranking.get('type_id'),
            'name': ranking.get('name'),
            'year': ranking.get('year'),
            'week': ranking.get('week'),
            'gender': ranking.get('gender'),
            'rank': competitor_ranking.get('rank'),
            'movement': competitor_ranking.get('movement'),
            'points': competitor_ranking.get('points'),
            'competitions_played': competitor_ranking.get('competitions_played'),
            'competitor_id': competitor.get('id'),
            'competitor_name': competitor.get('name'),
            'country_name': competitor.get('country'),
            'country_code': competitor.get('country_code'),
            'abbreviation': competitor.get('abbreviation')
        })

# Convert to a DataFrame
competitors_df = pd.DataFrame(flat_data)
competitor_rankings_df = pd.DataFrame(flat_data)

# Step 4: Store Data in a Relational Database
# Create a SQLite database
conn = sqlite3.connect('sports.db')
competitors_df.to_sql('Competitors', conn, if_exists='replace', index=False)
competitor_rankings_df.to_sql('Competitor_Rankings', conn, if_exists='replace', index=False)

# Verify the data was stored correctly
print("Data stored in the database:")
print(pd.read_sql_query("SELECT * FROM Competitors", conn))
# Out:
# Data stored in the database:
#      type_id name  year  week gender  rank  movement  points  \
# 0          2  ATP  2025     5    men     1         0    7530
# 1          2  ATP  2025     5    men     1         0    7530
# 2          2  ATP  2025     5    men     3        10    7075
# 3          2  ATP  2025     5    men     4        10    7055
# 4          2  ATP  2025     5    men     5        -2    6475
# ..       ...  ...   ...   ...    ...   ...       ...     ...
# 995        2  WTA  2025     5  women   496         7     124
# 996        2  WTA  2025     5  women   497        10     124
# 997        2  WTA  2025     5  women   498        12     124
# 998        2  WTA  2025     5  women   499        12     124
# 999        2  WTA  2025     5  women   500        12     123
#
#      competitions_played         competitor_id             competitor_name  \
# 0                     22   sr:competitor:49363                 Pavic, Mate
# 1                     22   sr:competitor:51836   Arevalo-Gonzalez, Marcelo
# 2                     31  sr:competitor:637970               Patten, Henry
# 3                     28   sr:competitor:14898           Heliovaara, Harri
# 4                     21   sr:competitor:87690            Thompson, Jordan
# ..                   ...                   ...                         ...
# 995                   10   sr:competitor:98733  Burillo Escorihuela, Irene
# 996                    4   sr:competitor:32862         Diatchenko, Vitalia
# 997                   15  sr:competitor:720627             Senic, Natalija
# 998                   21  sr:competitor:360054                Allen, Kolie
# 999                   17  sr:competitor:299308          Smith, Tina Nadine
#
#       country_name country_code abbreviation
# 0          Croatia          HRV          PAV
# 1      El Salvador          SLV          ARE
# 2    Great Britain          GBR          PAT
# 3          Finland          FIN          HEL
# 4        Australia          AUS          THO
# ..             ...          ...          ...
# 995          Spain          ESP          BUR
# 996        Neutral         None          DIA
# 997         Serbia          SRB          SEN
# 998            USA          USA          ALL
# 999      Australia          AUS          SMI
#
# [1000 rows x 14 columns]

# %%
import sqlite3

# Step 1: Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('sports.db')
cursor = conn.cursor()

# Step 2: Create the Categories Table
cursor.execute('''
CREATE TABLE IF NOT EXISTS Categories (
    category_id TEXT PRIMARY KEY,
    category_name TEXT NOT NULL
)
''')

# Step 3: Create the Competitions Table
cursor.execute('''
CREATE TABLE IF NOT EXISTS Competitions (
    competition_id TEXT PRIMARY KEY,
    competition_name TEXT NOT NULL,
    parent_id TEXT,
    type TEXT NOT NULL,
    gender TEXT NOT NULL,
    category_id TEXT,
    FOREIGN KEY (category_id) REFERENCES Categories(category_id)
)
''')

# Step 4: Create the Complexes Table
cursor.execute('''
CREATE TABLE IF NOT EXISTS Complexes (
    complex_id TEXT PRIMARY KEY,
    complex_name TEXT NOT NULL
)
''')

# Step 5: Create the Venues Table
cursor.execute('''
CREATE TABLE IF NOT EXISTS Venues (
    venue_id TEXT PRIMARY KEY,
    venue_name TEXT NOT NULL,
    city_name TEXT NOT NULL,
    country_name TEXT NOT NULL,
    country_code CHAR(3) NOT NULL,
    timezone TEXT NOT NULL,
    complex_id TEXT,
    FOREIGN KEY (complex_id) REFERENCES Complexes(complex_id)
)
''')

# Step 6: Create the Competitors Table
cursor.execute('''
CREATE TABLE IF NOT EXISTS Competitors (
    competitor_id TEXT PRIMARY KEY,
    name TEXT NOT NULL,
    country TEXT NOT NULL,
    country_code CHAR(3) NOT NULL,
    abbreviation TEXT NOT NULL
)
''')

# Step 7: Create the Competitor_Rankings Table
cursor.execute('''
CREATE TABLE IF NOT EXISTS Competitor_Rankings (
    rank_id INTEGER PRIMARY KEY AUTOINCREMENT,
    rank INTEGER NOT NULL,
    movement INTEGER NOT NULL,
    points INTEGER NOT NULL,
    competitions_played INTEGER NOT NULL,
    competitor_id TEXT,
    FOREIGN KEY (competitor_id) REFERENCES Competitors(competitor_id)
)
''')

# %%
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('sports.db')

# List all competitions along with their category name
query1 = '''
SELECT 
    c.id AS competition_id, 
    c.name AS competition_name, 
    c.type, 
    c.gender, 
    c.category_name 
FROM Competitions c;
'''
result1 = pd.read_sql_query(query1, conn)
print("List all competitions along with their category name:")
print(result1)

# Count the number of competitions in each category
query2 = '''
SELECT 
    c.category_name, 
    COUNT(c.id) AS competition_count 
FROM Competitions c
GROUP BY c.category_name;
'''
result2 = pd.read_sql_query(query2, conn)
print("Count the number of competitions in each category:")
print(result2)

# Find all competitions of type 'doubles'
query3 = '''
SELECT 
    id AS competition_id, 
    name AS competition_name, 
    type, 
    gender, 
    category_id 
FROM Competitions 
WHERE type = 'doubles';
'''
result3 = pd.read_sql_query(query3, conn)
print("Find all competitions of type 'doubles':")
print(result3)

# Get competitions that belong to a specific category (e.g., ITF Men)
query4 = '''
SELECT 
    id AS competition_id, 
    name AS competition_name, 
    type, 
    gender, 
    category_id 
FROM Competitions 
WHERE category_name = 'ITF Men';  -- Replace 'ITF Men' with the actual category name
'''
result4 = pd.read_sql_query(query4, conn)
print("Get competitions that belong to a specific category (e.g., ITF Men):")
print(result4)

# Analyze the distribution of competition types by category
query5 = '''
SELECT 
    c.category_name, 
    c.type, 
    COUNT(c.id) AS competition_count 
FROM Competitions c
GROUP BY c.category_name, c.type;
'''
result5 = pd.read_sql_query(query5, conn)
print("Analyze the distribution of competition types by category:")
print(result5)

# Close the connection
conn.close()
# Out:
# List all competitions along with their category name:
#             competition_id                   competition_name     type gender  \
# 0       sr:competition:620                         Hopman Cup    mixed  mixed
# 1       sr:competition:660                     World Team Cup    mixed    men
# 2       sr:competition:990         ATP Challenger Tour Finals  singles    men
# 3      sr:competition:1207  Championship International Series  singles  women
# 4      sr:competition:2100                          Davis Cup    mixed    men
# ...                    ...                                ...      ...    ...
# 5866  sr:competition:45841      UTR Cornella de Llobregat M03  singles    men
# 5867  sr:competition:45843                   UTR Berkeley M01  singles    men
# 5868  sr:competition:45845                   UTR Yokohama W02  singles  women
# 5869  sr:competition:45847      UTR Cornella de Llobregat W03  singles  women
# 5870  sr:competition:45849                    UTR Pancevo W01  singles  women
#
#      category_name
# 0       Hopman Cup
# 1              ATP
# 2       Challenger
# 3              WTA
# 4        Davis Cup
# ...            ...
# 5866       UTR Men
# 5867       UTR Men
# 5868     UTR Women
# 5869     UTR Women
# 5870     UTR Women
#
# [5871 rows x 5 columns]
# Count the number of competitions in each category:
#            category_name  competition_count
# 0                    ATP                220
# 1   Billie Jean King Cup                  1
# 2             Challenger                878
# 3              Davis Cup                  1
# 4             Exhibition                 32
# 5             Hopman Cup                  1
# 6                   IPTL                  1
# 7                ITF Men               2198
# 8              ITF Women               2032
# 9                Juniors                 16
# 10               Legends                 11
# 11               UTR Men                 26
# 12             UTR Women                 22
# 13            United Cup                  1
# 14                   WTA                253
# 15              WTA 125K                156
# 16           Wheelchairs                 16
# 17   Wheelchairs Juniors                  6
# Find all competitions of type 'doubles':
#             competition_id                                  competition_name  \
# 0      sr:competition:2557                             Wimbledon Men Doubles
# 1      sr:competition:2561                           Wimbledon Women Doubles
# 2      sr:competition:2569                       Australian Open Men Doubles
# 3      sr:competition:2573                     Australian Open Women Doubles
# 4      sr:competition:2581                           French Open Men Doubles
# ...                    ...                                               ...
# 2894  sr:competition:45797         WTA 125K Antalya 3, Turkiye Women Doubles
# 2895  sr:competition:45803    ATP Challenger Hersonissos, Greece Men Doubles
# 2896  sr:competition:45809  ATP Challenger Hersonissos 2, Greece Men Doubles
# 2897  sr:competition:45819         ATP Challenger Menorca, Spain Men Doubles
# 2898  sr:competition:45829                 WTA 125K Vic, Spain Women Doubles
#
#          type gender      category_id
# 0     doubles    men    sr:category:3
# 1     doubles  women    sr:category:6
# 2     doubles    men    sr:category:3
# 3     doubles  women    sr:category:6
# 4     doubles    men    sr:category:3
# ...       ...    ...              ...
# 2894  doubles  women  sr:category:871
# 2895  doubles    men   sr:category:72
# 2896  doubles    men   sr:category:72
# 2897  doubles    men   sr:category:72
# 2898  doubles  women  sr:category:871
#
# [2899 rows x 5 columns]
# Get competitions that belong to a specific category (e.g., ITF Men):
#             competition_id                                  competition_name  \
# 0      sr:competition:4143                 Dominican Republic F2 Men Singles
# 1      sr:competition:4145                 Dominican Republic F2 Men Doubles
# 2      sr:competition:4393  ITF Men Stuttgart-Stammheim, Germany Men Singles
# 3      sr:competition:4395  ITF Men Stuttgart-Stammheim, Germany Men Doubles
# 4      sr:competition:4577            ITF Men Cherkassy, Ukraine Men Singles
# ...                    ...                                               ...
# 2193  sr:competition:45213                         ITF Chile F4, Men Singles
# 2194  sr:competition:45283                  ITF South Africa F7, Men Singles
# 2195  sr:competition:45285                  ITF South Africa F7, Men Doubles
# 2196  sr:competition:45289                        ITF Spain F38, Men Singles
# 2197  sr:competition:45291                        ITF Spain F38, Men Doubles
#
#          type gender      category_id
# 0     singles    men  sr:category:785
# 1     doubles    men  sr:category:785
# 2     singles    men  sr:category:785
# 3     doubles    men  sr:category:785
# 4     singles    men  sr:category:785
# ...       ...    ...              ...
# 2193  singles    men  sr:category:785
# 2194  singles    men  sr:category:785
# 2195  doubles    men  sr:category:785
# 2196  singles    men  sr:category:785
# 2197  doubles    men  sr:category:785
#
# [2198 rows x 5 columns]
# Analyze the distribution of competition types by category:
#            category_name           type  competition_count
# 0                    ATP        doubles                106
# 1                    ATP          mixed                  2
# 2                    ATP  mixed_doubles                  5
# 3                    ATP        singles                107
# 4   Billie Jean King Cup          mixed                  1
# 5             Challenger        doubles                438
# 6             Challenger        singles                440
# 7              Davis Cup          mixed                  1
# 8             Exhibition        doubles                  8
# 9             Exhibition  mixed_doubles                  2
# 10            Exhibition        singles                 22
# 11            Hopman Cup          mixed                  1
# 12                  IPTL        singles                  1
# 13               ITF Men        doubles               1099
# 14               ITF Men        singles               1099
# 15             ITF Women        doubles               1018
# 16             ITF Women        singles               1014
# 17               Juniors        doubles                  8
# 18               Juniors        singles                  8
# 19               Legends        doubles                  8
# 20               Legends  mixed_doubles                  3
# 21               UTR Men        singles                 26
# 22             UTR Women        singles                 22
# 23            United Cup          mixed                  1
# 24                   WTA        doubles                126
# 25                   WTA        singles                127
# 26              WTA 125K        doubles                 78
# 27              WTA 125K        singles                 78
# 28           Wheelchairs        doubles                  8
# 29           Wheelchairs        singles                  8
# 30   Wheelchairs Juniors        doubles                  2
# 31   Wheelchairs Juniors        singles                  4

# %%
# Connect to SQLite database
conn = sqlite3.connect('sports.db')

# Query to check the column names in the Competitions table
query_check_columns = "PRAGMA table_info(Competitions);"
columns_info = pd.read_sql_query(query_check_columns, conn)
print(columns_info)

# Close the connection
conn.close()
# Out:
#    cid           name  type  notnull dflt_value  pk
# 0    0             id  TEXT        0       None   0
# 1    1           name  TEXT        0       None   0
# 2    2         gender  TEXT        0       None   0
# 3    3           type  TEXT        0       None   0
# 4    4    category_id  TEXT        0       None   0
# 5    5  category_name  TEXT        0       None   0

# %%
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('sports.db')

# List all venues along with their associated complex name
query1 = '''
SELECT 
    v.venue_id, 
    v.venue_name, 
    v.city_name, 
    v.country_name, 
    v.timezone, 
    c.complex_name 
FROM Venues v
JOIN Complexes c ON v.complex_id = c.complex_id;
'''
result1 = pd.read_sql_query(query1, conn)
print("List all venues along with their associated complex name:")
print(result1)

# Count the number of venues in each complex
query2 = '''
SELECT 
    c.complex_name, 
    COUNT(v.venue_id) AS venue_count 
FROM Venues v
JOIN Complexes c ON v.complex_id = c.complex_id
GROUP BY c.complex_name;
'''
result2 = pd.read_sql_query(query2, conn)
print("Count the number of venues in each complex:")
print(result2)

# Get details of venues in a specific country (e.g., Chile)
query3 = '''
SELECT 
    venue_id, 
    venue_name, 
    city_name, 
    country_name, 
    country_code, 
    timezone, 
    complex_id 
FROM Venues 
WHERE country_name = 'Chile';  -- Replace 'Chile' with the desired country
'''
result3 = pd.read_sql_query(query3, conn)
print("Get details of venues in a specific country (e.g., Chile):")
print(result3)

# Identify all venues and their timezones
query4 = '''
SELECT 
    venue_id, 
    venue_name, 
    timezone 
FROM Venues;
'''
result4 = pd.read_sql_query(query4, conn)
print("Identify all venues and their timezones:")
print(result4)

# Find complexes that have more than one venue
query5 = '''
SELECT 
    c.complex_name, 
    COUNT(v.venue_id) AS venue_count 
FROM Venues v
JOIN Complexes c ON v.complex_id = c.complex_id
GROUP BY c.complex_name
HAVING COUNT(v.venue_id) > 1;
'''
result5 = pd.read_sql_query(query5, conn)
print("Find complexes that have more than one venue:")
print(result5)

# List venues grouped by country
query6 = '''
SELECT 
    country_name, 
    COUNT(venue_id) AS venue_count 
FROM Venues 
GROUP BY country_name;
'''
result6 = pd.read_sql_query(query6, conn)
print("List venues grouped by country:")
print(result6)

# Find all venues for a specific complex (e.g., Nacional)
query7 = '''
SELECT 
    v.venue_id, 
    v.venue_name, 
    v.city_name, 
    v.country_name, 
    v.timezone 
FROM Venues v
JOIN Complexes c ON v.complex_id = c.complex_id
WHERE c.complex_name = 'Nacional';  -- Replace 'Nacional' with the desired complex name
'''
result7 = pd.read_sql_query(query7, conn)
print("Find all venues for a specific complex (e.g., Nacional):")
print(result7)

# Close the connection
conn.close()
# Out:
# List all venues along with their associated complex name:
#              venue_id             venue_name city_name country_name  \
# 0      sr:venue:70045         Cancha Central      None         None
# 1      sr:venue:74856           Centre Court      None         None
# 2      sr:venue:74856           Centre Court      None         None
# 3      sr:venue:74858              Court One      None         None
# 4      sr:venue:74858              Court One      None         None
# ...               ...                    ...       ...          ...
# 30768  sr:venue:81725  Bloomington - Court 5      None         None
# 30769  sr:venue:81765           Center Court      None         None
# 30770  sr:venue:81765           Center Court      None         None
# 30771  sr:venue:81767                Court 1      None         None
# 30772  sr:venue:81767                Court 1      None         None
#
#                timezone           complex_name
# 0      America/Santiago               Nacional
# 1         Europe/Madrid  Estadio de la Cartuja
# 2         Europe/Madrid  Estadio de la Cartuja
# 3         Europe/Madrid  Estadio de la Cartuja
# 4         Europe/Madrid  Estadio de la Cartuja
# ...                 ...                    ...
# 30768  America/New_York            Bloomington
# 30769    Asia/Singapore  Kallang Tennis Centre
# 30770    Asia/Singapore  Kallang Tennis Centre
# 30771    Asia/Singapore  Kallang Tennis Centre
# 30772    Asia/Singapore  Kallang Tennis Centre
#
# [30773 rows x 6 columns]
# Count the number of venues in each complex:
#                                           complex_name  venue_count
# 0                              A.S.D. Tennis Club Como           81
# 1                                          AAJB Tennis          121
# 2    AELTC Wimbledon Qualifying and Community Sport...          400
# 3                                             AO Arena            1
# 4                                     ASB Tennis Arena          196
# ..                                                 ...          ...
# 468                                  XS Tennis Village          169
# 469                            Yokkaichi Tennis Center           81
# 470                               Yucatan Country Club           25
# 471      Zayed Sports City International Tennis Centre           49
# 472                                ŠRC MARINA PORTOROŽ           36
#
# [473 rows x 2 columns]
# Get details of venues in a specific country (e.g., Chile):
# Empty DataFrame
# Columns: [venue_id, venue_name, city_name, country_name, country_code, timezone, complex_id]
# Index: []
# Identify all venues and their timezones:
#             venue_id             venue_name          timezone
# 0     sr:venue:70045         Cancha Central  America/Santiago
# 1     sr:venue:74856           Centre Court     Europe/Madrid
# 2     sr:venue:74858              Court One     Europe/Madrid
# 3      sr:venue:1496                COURT 1     Europe/Moscow
# 4      sr:venue:1500           CENTER COURT     Europe/Moscow
# ...              ...                    ...               ...
# 3200  sr:venue:81721  Bloomington - Court 7  America/New_York
# 3201  sr:venue:81723  Bloomington - Court 6  America/New_York
# 3202  sr:venue:81725  Bloomington - Court 5  America/New_York
# 3203  sr:venue:81765           Center Court    Asia/Singapore
# 3204  sr:venue:81767                Court 1    Asia/Singapore
#
# [3205 rows x 3 columns]
# Find complexes that have more than one venue:
#                                           complex_name  venue_count
# 0                              A.S.D. Tennis Club Como           81
# 1                                          AAJB Tennis          121
# 2    AELTC Wimbledon Qualifying and Community Sport...          400
# 3                                     ASB Tennis Arena          196
# 4                         ATP Stadion Goran Ivanisevic           64
# ..                                                 ...          ...
# 440                                  XS Tennis Village          169
# 441                            Yokkaichi Tennis Center           81
# 442                               Yucatan Country Club           25
# 443      Zayed Sports City International Tennis Centre           49
# 444                                ŠRC MARINA PORTOROŽ           36
#
# [445 rows x 2 columns]
# List venues grouped by country:
#   country_name  venue_count
# 0         None         3205
# Find all venues for a specific complex (e.g., Nacional):
#          venue_id      venue_name city_name country_name          timezone
# 0  sr:venue:70045  Cancha Central      None         None  America/Santiago

# %%
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('sports.db')

# Get all competitors with their rank and points
query1 = '''
SELECT 
    competitor_id, 
    competitor_name AS name, 
    rank, 
    points 
FROM Competitors;
'''
result1 = pd.read_sql_query(query1, conn)
print("Get all competitors with their rank and points:")
print(result1)

# Find competitors ranked in the top 5
query2 = '''
SELECT 
    competitor_id, 
    competitor_name AS name, 
    rank, 
    points 
FROM Competitors 
WHERE rank <= 5
ORDER BY rank ASC;
'''
result2 = pd.read_sql_query(query2, conn)
print("Find competitors ranked in the top 5:")
print(result2)

# List competitors with no rank movement (stable rank)
query3 = '''
SELECT 
    competitor_id, 
    competitor_name AS name, 
    rank, 
    points 
FROM Competitors 
WHERE movement = 0;
'''
result3 = pd.read_sql_query(query3, conn)
print("List competitors with no rank movement (stable rank):")
print(result3)

# Get the total points of competitors from a specific country (e.g., Croatia)
query4 = '''
SELECT 
    country_name, 
    SUM(points) AS total_points 
FROM Competitors 
WHERE country_name = 'Croatia'  -- Replace 'Croatia' with the desired country
GROUP BY country_name;
'''
result4 = pd.read_sql_query(query4, conn)
print("Get the total points of competitors from a specific country (e.g., Croatia):")
print(result4)

# Count the number of competitors per country
query5 = '''
SELECT 
    country_name, 
    COUNT(competitor_id) AS competitor_count 
FROM Competitors 
GROUP BY country_name;
'''
result5 = pd.read_sql_query(query5, conn)
print("Count the number of competitors per country:")
print(result5)

# Find competitors with the highest points in the current week
query6 = '''
SELECT 
    competitor_id, 
    competitor_name AS name, 
    rank, 
    points 
FROM Competitors 
ORDER BY points DESC
LIMIT 1;
'''
result6 = pd.read_sql_query(query6, conn)
print("Find competitors with the highest points in the current week:")
print(result6)

# Close the connection
conn.close()
# Out:
# Get all competitors with their rank and points:
#             competitor_id                        name  rank  points
# 0     sr:competitor:49363                 Pavic, Mate     1    7530
# 1     sr:competitor:51836   Arevalo-Gonzalez, Marcelo     1    7530
# 2    sr:competitor:637970               Patten, Henry     3    7075
# 3     sr:competitor:14898           Heliovaara, Harri     4    7055
# 4     sr:competitor:87690            Thompson, Jordan     5    6475
# ..                    ...                         ...   ...     ...
# 995   sr:competitor:98733  Burillo Escorihuela, Irene   496     124
# 996   sr:competitor:32862         Diatchenko, Vitalia   497     124
# 997  sr:competitor:720627             Senic, Natalija   498     124
# 998  sr:competitor:360054                Allen, Kolie   499     124
# 999  sr:competitor:299308          Smith, Tina Nadine   500     123
#
# [1000 rows x 4 columns]
# Find competitors ranked in the top 5:
#           competitor_id                       name  rank  points
# 0   sr:competitor:49363                Pavic, Mate     1    7530
# 1   sr:competitor:51836  Arevalo-Gonzalez, Marcelo     1    7530
# 2   sr:competitor:72376        Siniakova, Katerina     1   10750
# 3   sr:competitor:74949            Routliffe, Erin     2    8165
# 4  sr:competitor:637970              Patten, Henry     3    7075
# 5   sr:competitor:51387           Townsend, Taylor     3    7378
# 6   sr:competitor:14898          Heliovaara, Harri     4    7055
# 7   sr:competitor:43860        Dabrowski, Gabriela     4    6805
# 8   sr:competitor:87690           Thompson, Jordan     5    6475
# 9   sr:competitor:64496          Ostapenko, Jelena     5    5360
# List competitors with no rank movement (stable rank):
#            competitor_id                       name  rank  points
# 0    sr:competitor:49363                Pavic, Mate     1    7530
# 1    sr:competitor:51836  Arevalo-Gonzalez, Marcelo     1    7530
# 2    sr:competitor:22967              Bhambri, Yuki    47    1895
# 3    sr:competitor:62410              Johnson, Luke    53    1658
# 4    sr:competitor:25457      Nedovyesov, Aleksandr    60    1401
# ..                   ...                        ...   ...     ...
# 60   sr:competitor:98523                 Ye, Qiu Yu   420     159
# 61  sr:competitor:389048            Weckerle, Marie   421     159
# 62  sr:competitor:171354             Romero, Camila   423     158
# 63  sr:competitor:185412          Labrana, Fernanda   443     146
# 64   sr:competitor:71034          Sramkova, Rebecca   478     130
#
# [65 rows x 4 columns]
# Get the total points of competitors from a specific country (e.g., Croatia):
#   country_name  total_points
# 0      Croatia         16976
# Count the number of competitors per country:
#            country_name  competitor_count
# 0               Algeria                 1
# 1   Antigua and Barbuda                 1
# 2             Argentina                31
# 3               Armenia                 1
# 4             Australia                53
# ..                  ...               ...
# 75              Ukraine                19
# 76              Uruguay                 3
# 77           Uzbekistan                 1
# 78            Venezuela                 3
# 79             Zimbabwe                 2
#
# [80 rows x 2 columns]
# Find competitors with the highest points in the current week:
#          competitor_id                 name  rank  points
# 0  sr:competitor:72376  Siniakova, Katerina     1   10750

# %%
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('sports.db')

# Query to check the column names in the Competitors table
query_check_columns_competitors = "PRAGMA table_info(Competitors);"
columns_info_competitors = pd.read_sql_query(query_check_columns_competitors, conn)
print("Competitors Table Columns:")
print(columns_info_competitors)

# Query to check the column names in the Competitor_Rankings table
query_check_columns_rankings = "PRAGMA table_info(Competitor_Rankings);"
columns_info_rankings = pd.read_sql_query(query_check_columns_rankings, conn)
print("Competitor_Rankings Table Columns:")
print(columns_info_rankings)

# Close the connection
conn.close()
# Out:
# Competitors Table Columns:
#     cid                 name     type  notnull dflt_value  pk
# 0     0              type_id  INTEGER        0       None   0
# 1     1                 name     TEXT        0       None   0
# 2     2                 year  INTEGER        0       None   0
# 3     3                 week  INTEGER        0       None   0
# 4     4               gender     TEXT        0       None   0
# 5     5                 rank  INTEGER        0       None   0
# 6     6             movement  INTEGER        0       None   0
# 7     7               points  INTEGER        0       None   0
# 8     8  competitions_played  INTEGER        0       None   0
# 9     9        competitor_id     TEXT        0       None   0
# 10   10      competitor_name     TEXT        0       None   0
# 11   11         country_name     TEXT        0       None   0
# 12   12         country_code     TEXT        0       None   0
# 13   13         abbreviation     TEXT        0       None   0
# Competitor_Rankings Table Columns:
#     cid                 name     type  notnull dflt_value  pk
# 0     0              type_id  INTEGER        0       None   0
# 1     1                 name     TEXT        0       None   0
# 2     2                 year  INTEGER        0       None   0
# 3     3                 week  INTEGER        0       None   0
# 4     4               gender     TEXT        0       None   0
# 5     5                 rank  INTEGER        0       None   0
# 6     6             movement  INTEGER        0       None   0
# 7     7               points  INTEGER        0       None   0
# 8     8  competitions_played  INTEGER        0       None   0
# 9     9        competitor_id     TEXT        0       None   0
# 10   10      competitor_name     TEXT        0       None   0
# 11   11         country_name     TEXT        0       None   0
# 12   12         country_code     TEXT        0       None   0
# 13   13         abbreviation     TEXT        0       None   0

# %% [markdown]
# ***Verify Database and Table Creation Ensure that the sports.db file exists and contains the Competitors table***

# %%
import sqlite3
import os

# Database file path
db_file_path = 'sports.db'

# Create the database file if it doesn't exist
if not os.path.exists(db_file_path):
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    # Create the Competitors table
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS Competitors (
        id INTEGER PRIMARY KEY,
        competitor_name TEXT,
        country_name TEXT,
        rank INTEGER,
        points INTEGER,
        gender TEXT,
        year INTEGER
    )
    ''')

    # Commit the changes and close the connection
    conn.commit()
    conn.close()
